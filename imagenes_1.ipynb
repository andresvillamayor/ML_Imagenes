# %% [markdown]
# <a href="https://colab.research.google.com/github/andresvillamayor/ML_Imagenes/blob/main/imagenes_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagen = cv2.imread('/content/manzana.png')
plt.imshow(imagen)
plt.show()
